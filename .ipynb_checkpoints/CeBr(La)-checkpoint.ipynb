# %%
import sympy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %% [markdown]
# # CeBr(La) (CH0)

# %%
background_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\Background 27_11\Energy_ch0.txt", skiprows=1)
channels = background_wrong[:, 0]
counts = background_wrong[:, 1]

# %%
range_ = (channels >= 0) & (channels <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels[range_], counts[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
background = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\17_12 background\17_12 background\Energy_ch0.txt", skiprows=1)
channels0 = background[:, 0]
counts0 = background[:, 1]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-42f7fda4b088> in <module>
# ----> 1 background = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\17_12 background\17_12 background\Energy_ch0.txt", skiprows=1)
#       2 channels0 = background[:, 0]
#       3 counts0 = background[:, 1]
#
# C:\SymPy\Installatie\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# C:\SymPy\Installatie\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
# ...

# %%
range_ = (channels0 >= 0) & (channels0 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels0[range_], counts0[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ---

# %%
am241_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\241Am 20_11\Energy_ch0.txt", skiprows=1)
channels1 = am241_wrong[:, 0]
counts1 = am241_wrong[:, 1]

# %%
range_ = (channels1 >= 0) & (channels1 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels1[range_], counts1[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
cs137_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\137Cs 27_11\Energy_ch0.txt", skiprows=1)
channels2 = cs137_wrong[:, 0]
counts2 = cs137_wrong[:, 1]

# %%
range_ = (channels2 >= 0) & (channels2 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels2[range_], counts2[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
am241_cs137_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\241Am_137Cs 15_12 oscilloscope_on\Energy_ch0.txt", skiprows=1)
channels3_0 = am241_cs137_wrong[:, 0]
counts3_0 = am241_cs137_wrong[:, 1]

# %%
range_ = (channels3_0 >= 0) & (channels3_0 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels3_0[range_], counts3_0[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
am241_cs137 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\241Am_137Cs 15_12\Energy_ch0.txt", skiprows=1)
channels3 = am241_cs137[:, 0]
counts3 = am241_cs137[:, 1]

# %%
range_ = (channels3 >= 0) & (channels3 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels3[range_], counts3[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ---

# %%
co60_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\60Co 20_11\Energy_ch0.txt", skiprows=1)
channels4 = co60_wrong[:, 0]
counts4 = co60_wrong[:, 1]

# %%
range_ = (channels4 >= 0) & (channels4 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels4[range_], counts4[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
co60 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\60Co 15_12\Energy_ch0.txt", skiprows=1)
channels5 = co60[:, 0]
counts5 = co60[:, 1]

# %%
range_ = (channels5 >= 0) & (channels5 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels5[range_], counts5[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ---

# %%
eu152_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\152Eu 27_11\Energy_ch0.txt", skiprows=1)
channels6 = eu152_wrong[:, 0]
counts6 = eu152_wrong[:, 1]

# %%
range_ = (channels6 >= 0) & (channels6 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels6[range_], counts6[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %%
eu152 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\152Eu 15_12\Energy_ch0.txt", skiprows=1)
channels7 = eu152[:, 0]
counts7 = eu152[:, 1]

# %%
range_ = (channels7 >= 0) & (channels7 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels7[range_], counts7[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ---

# %%
na22_wrong = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\22Na 27_11\Energy_ch0.txt", skiprows=1)
channels8 = na22_wrong[:, 0]
counts8 = na22_wrong[:, 1]

# %%
range_ = (channels8 >= 0) & (channels8 <= 3500)
plt.figure(figsize=(12, 4))
plt.plot(channels8[range_], counts8[range_])
plt.xlabel("ADC Channel")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ---

# %%
text = input("Enter your text: ")
old_number = input("Enter the number you want to replace: ")
new_number = input("Enter the new number: ")

updated_text = text.replace(old_number, new_number)
print(updated_text)
