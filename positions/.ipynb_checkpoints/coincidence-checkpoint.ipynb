# %%
import sympy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy.optimize import root_scalar
from datetime import date

# %% [markdown]
# # Load data and get time

# %% [markdown]
# ### background

# %% [markdown]
# #### 17/12

# %%
bg = {}

coinc1 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\17_12 background\Coincidence_histo.txt", skiprows=1)
timestamps1 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\17_12 background\Timestamp_ch0.txt", skiprows=1)

ctime1 = coinc1[:, 0]
counts1 = coinc1[:, 1]
t1 = timestamps1[:, 0]
time1 = (t1[-1] - t1[0]) * 1e-12

bg["d"] = {
    "ctime": ctime1,
    "counts": counts1,
    "time": time1
}

# %% [markdown]
# #### 18/03

# %%
coinc2 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\18_03_background\Coincidence_histo.txt", skiprows=1)
timestamps2 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\18_03_background\Timestamp_ch0.txt", skiprows=1)

ctime2 = coinc2[:, 0]
counts2 = coinc2[:, 1]
t2 = timestamps2[:, 0]
time2 = (t2[-1] - t2[0]) * 1e-12

bg["m"] = {
    "ctime": ctime2,
    "counts": counts2,
    "time": time2
}

# %% [markdown]
# #### 01/04

# %%
coinc3 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\01_04_background\Coincidence_histo.txt", skiprows=1)
timestamps3 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\01_04_background\Timestamp_ch0.txt", skiprows=1)

ctime3 = coinc3[:, 0]
counts3 = coinc3[:, 1]
t3 = timestamps3[:, 0]
time3 = (t3[-1] - t3[0]) * 1e-12

bg["a1"] = {
    "ctime": ctime3,
    "counts": counts3,
    "time": time3
}

# %% [markdown]
# #### 22/04

# %%
coinc4 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\22_04_bg_10min\Coincidence_histo.txt", skiprows=1)
timestamps4 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\22_04_bg_10min\Timestamp_ch0.txt", skiprows=1)

ctime4 = coinc4[:, 0]
counts4 = coinc4[:, 1]
t4 = timestamps4[:, 0]
time4 = (t4[-1] - t4[0]) * 1e-12

bg["min10"] = {
    "ctime": ctime4,
    "counts": counts4,
    "time": time4
}

# %% [markdown]
# #### 21/04

# %%
coinc5 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\21_04_Background\Coincidence_histo.txt", skiprows=1)
timestamps5 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\21_04_Background\Timestamp_ch0.txt", skiprows=1)

ctime5 = coinc5[:, 0]
counts5 = coinc5[:, 1]
t5 = timestamps5[:, 0]
time5 = (t5[-1] - t5[0]) * 1e-12

bg["min2"] = {
    "ctime": ctime5,
    "counts": counts5,
    "time": time5
}

# %% [markdown]
# #### 05/05

# %%
coinc6 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\05_05_bg_5min\Coincidence_histo.txt", skiprows=1)
timestamps6 = np.loadtxt(r"C:\Users\linde\Downloads\IRDNI_PET\positions\05_05_bg_5min\Timestamp_ch0.txt", skiprows=1)

ctime6 = coinc6[:, 0]
counts6 = coinc6[:, 1]
t6 = timestamps6[:, 0]
time6 = (t6[-1] - t6[0]) * 1e-12

bg["m5"] = {
    "ctime": ctime6,
    "counts": counts6,
    "time": time6
}

# %% [markdown]
# ### Na22

# %% [markdown]
# #### 17/12

# %%
na22d = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\17_12 Na22 pos{}"

for i in range(1, 10):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22d[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# #### 18/03

# %%
na22m = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\18_03_Na22Pos{}"

for i in range(1, 21):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22m[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# #### 01/04

# %%
na22a1 = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\01_04_Na22_pos{}"

for i in range(1, 15):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22a1[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# #### 22/04

# %%
na22min10 = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\22_04_Na22_pos{}"

for i in range(1, 34):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22min10[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# #### 21/04

# %%
na22min2 = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\21_04_Na22_pos{}"

for i in range(1, 22):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22min2[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# #### 05/05

# %%
na22m5 = {}
base_path = r"C:\Users\linde\Downloads\IRDNI_PET\positions\05_05_Na22_pos{}"

for i in range(1, 12):
    path = base_path.format(i)
    
    coinc = np.loadtxt(f"{path}\\Coincidence_histo.txt", skiprows=1)
    timestamps = np.loadtxt(f"{path}\\Timestamp_ch0.txt", skiprows=1)
    
    ctime = coinc[:, 0]
    counts = coinc[:, 1]
    t = timestamps[:, 0]
    time = (t[-1] - t[0]) * 1e-12
    
    na22m5[f"{i}"] = {
        "ctime": ctime,
        "counts": counts,
        "time": time
    }

# %% [markdown]
# ---

# %% [markdown]
# # Subtract background

# %% [markdown]
# ### background

# %% [markdown]
# #### 17/12

# %%
#spectrum background
range_bg = (bg["d"]["ctime"] > -2000) & (bg["d"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["d"]["ctime"][range_bg], bg["d"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #### 18/03

# %%
#spectrum background
range_bg = (bg["m"]["ctime"] > -2000) & (bg["m"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["m"]["ctime"][range_bg], bg["m"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #### 01/04

# %%
#spectrum background
range_bg = (bg["a1"]["ctime"] > -2000) & (bg["a1"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["a1"]["ctime"][range_bg], bg["a1"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #### 22/04

# %%
#spectrum background
range_bg = (bg["min10"]["ctime"] > -2000) & (bg["min10"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["min10"]["ctime"][range_bg], bg["min10"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #### 21/04

# %%
#spectrum background
range_bg = (bg["min2"]["ctime"] > -2000) & (bg["min2"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["min2"]["ctime"][range_bg], bg["min2"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# #### 05/05

# %%
#spectrum background
range_bg = (bg["m5"]["ctime"] > -2000) & (bg["m5"]["ctime"] < 2000)
plt.figure(figsize=(8, 4))
plt.plot(bg["m5"]["ctime"][range_bg], bg["m5"]["counts"][range_bg])
plt.xlabel("Time")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ### Na22

# %% [markdown]
# #### 17/12

# %%
for key in na22d:
    counts_bg_na22 = bg["d"]["counts"] * (na22d[key]["time"] / bg["d"]["time"])
    na22d[key]["netcounts"] = na22d[key]["counts"] - counts_bg_na22
    na22d[key]["netcounts"][na22d[key]["netcounts"] < 0] = 0

# %%
for key in na22d:
    range_na22 = (na22d[key]["ctime"] > -100) & (na22d[key]["ctime"] < 100)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22d[key]["ctime"][range_na22], na22d[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22d[key]["ctime"][range_na22], na22d[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 18/03

# %%
for key in na22m:
    counts_bg_na22 = bg["m"]["counts"] * (na22m[key]["time"] / bg["m"]["time"])
    na22m[key]["netcounts"] = na22m[key]["counts"] - counts_bg_na22
    na22m[key]["netcounts"][na22m[key]["netcounts"] < 0] = 0

# %%
for key in na22m:
    range_na22 = (na22m[key]["ctime"] > -2000) & (na22m[key]["ctime"] < 2000)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22m[key]["ctime"][range_na22], na22m[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22m[key]["ctime"][range_na22], na22m[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    display(plt.gcf())  
    plt.close()

# %% [markdown]
# #### 01/04

# %%
for key in na22a1:
    counts_bg_na22 = bg["a1"]["counts"] * (na22a1[key]["time"] / bg["a1"]["time"])
    na22a1[key]["netcounts"] = na22a1[key]["counts"] - counts_bg_na22
    na22a1[key]["netcounts"][na22a1[key]["netcounts"] < 0] = 0

# %%
for key in na22a1:
    range_na22 = (na22a1[key]["ctime"] > -2000) & (na22a1[key]["ctime"] < 2000)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22a1[key]["ctime"][range_na22], na22a1[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22a1[key]["ctime"][range_na22], na22a1[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    display(plt.gcf())  
    plt.close()

# %% [markdown]
# #### 22/04

# %%
for key in na22min10:
    counts_bg_na22 = bg["min10"]["counts"] * (na22min10[key]["time"] / bg["min10"]["time"])
    na22min10[key]["netcounts"] = na22min10[key]["counts"] - counts_bg_na22
    na22min10[key]["netcounts"][na22min10[key]["netcounts"] < 0] = 0

# %%
for key in na22min10:
    range_na22 = (na22min10[key]["ctime"] > -2000) & (na22min10[key]["ctime"] < 2000)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22min10[key]["ctime"][range_na22], na22min10[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22min10[key]["ctime"][range_na22], na22min10[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    display(plt.gcf())  
    plt.close()

# %% [markdown]
# #### 21/04

# %%
for key in na22min2:
    counts_bg_na22 = bg["min2"]["counts"] * (na22min2[key]["time"] / bg["min2"]["time"])
    na22min2[key]["netcounts"] = na22min2[key]["counts"] - counts_bg_na22
    na22min2[key]["netcounts"][na22min2[key]["netcounts"] < 0] = 0

# %%
for key in na22min2:
    range_na22 = (na22min2[key]["ctime"] > -2000) & (na22min2[key]["ctime"] < 2000)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22min2[key]["ctime"][range_na22], na22min2[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22min2[key]["ctime"][range_na22], na22min2[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    display(plt.gcf())  
    plt.close()

# %% [markdown]
# #### 05/05

# %%
for key in na22m5:
    counts_bg_na22 = bg["m5"]["counts"] * (na22m5[key]["time"] / bg["m5"]["time"])
    na22m5[key]["netcounts"] = na22m5[key]["counts"] - counts_bg_na22
    na22m5[key]["netcounts"][na22m5[key]["netcounts"] < 0] = 0

# %%
for key in na22m5:
    range_na22 = (na22m5[key]["ctime"] > -2000) & (na22m5[key]["ctime"] < 2000)
    
    fig, ax = plt.subplots(1, 2, figsize=(14,4)) 
    
    ax[0].plot(na22m5[key]["ctime"][range_na22], na22m5[key]["counts"][range_na22])
    ax[0].set_title(f"Na22 pos{key} with background")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("Counts")

    ax[1].plot(na22m5[key]["ctime"][range_na22], na22m5[key]["netcounts"][range_na22])
    ax[1].set_title(f"Na22 pos{key} background subtracted")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    display(plt.gcf())  
    plt.close()

# %% [markdown]
# ---

# %% [markdown]
# # Statistical errors

# %% [markdown]
# #### 17/12

# %%
for key in na22d:
    na22d[key]["sigma_counts"] = np.sqrt(na22d[key]["counts"] + (na22d[key]["time"] / bg["d"]["time"])**2 * bg["d"]["counts"])
    na22d[key]["sigma_counts"][na22d[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# #### 18/03

# %%
for key in na22m:
    na22m[key]["sigma_counts"] = np.sqrt(na22m[key]["counts"] + (na22m[key]["time"] / bg["m"]["time"])**2 * bg["m"]["counts"])
    na22m[key]["sigma_counts"][na22m[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# #### 01/04

# %%
for key in na22a1:
    na22a1[key]["sigma_counts"] = np.sqrt(na22a1[key]["counts"] + (na22a1[key]["time"] / bg["a1"]["time"])**2 * bg["a1"]["counts"])
    na22a1[key]["sigma_counts"][na22a1[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# #### 22/04

# %%
for key in na22min10:
    na22min10[key]["sigma_counts"] = np.sqrt(na22min10[key]["counts"] + (na22min10[key]["time"] / bg["min10"]["time"])**2 * bg["min10"]["counts"])
    na22min10[key]["sigma_counts"][na22min10[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# #### 21/04

# %%
for key in na22min2:
    na22min2[key]["sigma_counts"] = np.sqrt(na22min2[key]["counts"] + (na22min2[key]["time"] / bg["min2"]["time"])**2 * bg["min2"]["counts"])
    na22min2[key]["sigma_counts"][na22min2[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# #### 05/05

# %%
for key in na22m5:
    na22m5[key]["sigma_counts"] = np.sqrt(na22m5[key]["counts"] + (na22m5[key]["time"] / bg["m5"]["time"])**2 * bg["m5"]["counts"])
    na22m5[key]["sigma_counts"][na22m5[key]["sigma_counts"] == 0] = 1

# %% [markdown]
# ---

# %% [markdown]
# # Get counts

# %% [markdown]
# #### 17/12

# %%
for key in na22d:
    indices = np.argsort(na22d[key]["netcounts"])[-5:][::-1]
    print(indices)
# Out:
# [198 199 197 129 217]
# [198 199 197 200 373]
# [198 199 200  77 372]
# [198 199 197 200 344]
# [198 199 147 201  40]
# [198 199 197 200 221]
# [198 199 197 200 311]
# [198 199 200 174 171]
# [198 199 200 197 188]

# %%
countsd = []
counts_errd = []
for key in na22d:
    counts = na22d[key]["netcounts"][198] + na22d[key]["netcounts"][199]
    countsd.append(counts)
    error = np.sqrt(na22d[key]["sigma_counts"][198]**2 + na22d[key]["sigma_counts"][199]**2)
    counts_errd.append(error)
print(countsd)
print(counts_errd)
print(len(countsd))
# Out:
# [4732.100097025379, 4324.5962006379, 3578.9761452681987, 549.717791081606, 508.02266205888765, 4448.070764415494, 3492.8624376458592, 4340.209247100858, 3729.5551589834504]
# [72.54502850912434, 69.76138037401724, 64.46834343137905, 32.54561227255953, 31.734669257677098, 70.31250996920551, 63.361300837202414, 69.53814637148407, 65.13637556803893]
# 9

# %% [markdown]
# #### 18/03

# %%
for key in na22m:
    indices = np.argsort(na22m[key]["netcounts"])[-5:][::-1]
    print(indices)
    print(na22m[key]["netcounts"][197:200])
# Out:
# [198 199 197 200 309]
# [   5.02795228 1359.87280255 1024.4535184 ]
# [198 199  67 200 197]
# [1.02787765e+00 1.24286780e+03 1.05244964e+03]
# [198 199 260 219 170]
# [  0.         748.86758543 579.44946929]
# [198 199 192 197 168]
# [   2.02791984 1281.87062904  975.4518315 ]
# [198 199  67 384  53]
# [2.79165866e-02 7.38870411e+02 6.57451663e+02]
# [198 199 158 212 175]
# [2.78711628e-02 1.26867368e+02 1.17449300e+02]
# [198 199 200  66 133]
# [   0.         1235.87215063 1121.45301243]
# [198 199 200 244  63]
# [  0.         110.86867241  96.45031291]
# [199 198 139 220 161]
# [2.79036130e-02 5.68695421e+01 8.64509879e+01]
# [198 199 325  55 250]
# [  0.         142.87062882  97.45183133]
# [198 199 197 111 166]
# [  5.02787441 871.86758565 573.44946946]
# [198 199 381 109 117]
# [  0.         145.87258524 120.45334974]
# [198 199 325 372  36]
# [2.78452124e-02 8.18656292e+01 5.34479510e+01]
# [198 199 191 295  16]
# [2.79912138e-02 1.19875411e+02 8.84555431e+01]
# [198 199 200 288  50]
# [  0.         265.87236772 237.45318092]
# [198 199  62 134 389]
# [2.79198364e-02 9.55870629e+02 7.80451831e+02]
# [198 199 200  94  73]
# [2.79652569e-02 1.18487367e+03 9.55454193e+02]
# [198 199 276 275 348]
# [2.78938763e-02 8.81868890e+02 6.83450482e+02]
# [198 199 197  19  73]
# [  3.02788415 255.86823779 206.4499756 ]
# [199 198 338 132  29]
# [  0.         104.86954185 113.45098771]

# %%
countsm = []
counts_errm = []
for key in na22m:
    counts = na22m[key]["netcounts"][198] + na22m[key]["netcounts"][199]
    countsm.append(counts)
    error = np.sqrt(na22m[key]["sigma_counts"][198]**2 + na22m[key]["sigma_counts"][199]**2)
    counts_errm.append(error)
print(countsm)
print(counts_errm)
print(len(countsm))
# Out:
# [2384.3263209481474, 2295.317440688316, 1328.3170547245795, 2257.3224605373107, 1396.3220738001, 244.31666837410603, 2357.3251630569393, 207.3189853167353, 143.32052994515485, 240.32246015057345, 1445.3170551113167, 266.32593498441156, 135.31358027747862, 208.33095444666918, 503.32554863393807, 1736.3224605373107, 2140.327865576567, 1565.3193712804714, 462.3182133892627, 218.32052955841763]
# [51.11203709839614, 50.23402831829441, 39.4519752546359, 49.85426603090437, 40.30444880358227, 21.736124370642102, 50.84724758932499, 20.867548920935697, 19.27307953836603, 21.643655934986224, 40.907925280322985, 22.23603127132665, 19.064760863743505, 20.890938910562674, 27.045181415649136, 44.32209202508592, 48.66659360858119, 42.349189455891235, 26.276531330609558, 21.12940121357146]
# 20

# %% [markdown]
# #### 01/04

# %%
for key in na22a1:
    indices = np.argsort(na22a1[key]["netcounts"])[-5:][::-1]
    print(indices)
# Out:
# [198 199 323 296 289]
# [198 199 197 356  18]
# [198 199 341 132 174]
# [198 199 197 229  50]
# [198 199 197  92 324]
# [198 199  98 243 102]
# [198 199 197 200 263]
# [198 199 363 349 332]
# [198 199 318 356 197]
# [198 199  91 242 334]
# [198 199 197 200 339]
# [198 199 197  74 291]
# [198 199 177 340 219]
# [198 199 200  54 114]

# %%
countsa1 = []
counts_erra1 = []
for key in na22a1:
    counts = na22a1[key]["netcounts"][198] + na22a1[key]["netcounts"][199]
    countsa1.append(counts)
    error = np.sqrt(na22a1[key]["sigma_counts"][198]**2 + na22a1[key]["sigma_counts"][199]**2)
    counts_erra1.append(error)
print(countsa1)
print(counts_erra1)
print(len(countsa1))
# Out:
# [2160.98696871418, 2481.988597879847, 2543.997964154771, 2558.994705823437, 1948.98615453925, 1720.9857474517848, 1543.9959274937357, 1517.9975566594028, 455.99714997984086, 225.98737620954853, 1621.9869687141802, 503.99266997820826, 220.98737580164527, 1733.9869687141802]
# [49.041065077785184, 52.21132832351565, 52.801553686652355, 52.9434659668487, 46.82977356866874, 44.328642058622464, 42.28484533669804, 41.97624193195632, 26.457620832321584, 21.68006570301698, 43.197523817500944, 27.349856681233028, 21.564444108370243, 44.475004934947016]
# 14

# %% [markdown]
# #### 22/04

# %%
for key in na22min10:
    indices = np.argsort(na22min10[key]["netcounts"])[-5:][::-1]
    print(indices)
# Out:
# [198 199 197 106 306]
# [198 199 197 206 319]
# [198 199 197 200 329]
# [198 199 181 109 200]
# [198 199 197 237 200]
# [198 199 197 288 128]
# [198 199 197 182 398]
# [198 199 197 200 319]
# [198 199 320  76 182]
# [198 199 190 188 189]
# [198 199 197 200   2]
# [198 199 197  46  90]
# [198 199 313 124 193]
# [198 199 228 212 275]
# [198 199 280 279 200]
# [198 199 360 196 165]
# [198 199 197  79 201]
# [198 199 197 151 323]
# [198 199 197 201 306]
# [198 199 201 203  56]
# [198 199 330  96 100]
# [198 199 200 285 259]
# [198 199   5 197 382]
# [198 199 200 288 364]
# [198 199 350 387 106]
# [198 199 197 202  43]
# [198 199 200 130  62]
# [199 198 351 129 315]
# [198 199  38 261 372]
# [198 199 197 264 390]
# [198 199 248 105  31]
# [198 199  87 113 326]
# [198 199 197 372 292]

# %%
countsmin10 = []
counts_errmin10 = []
for key in na22min10:
    counts = na22min10[key]["netcounts"][198] + na22min10[key]["netcounts"][199]
    countsmin10.append(counts)
    error = np.sqrt(na22min10[key]["sigma_counts"][198]**2 + na22min10[key]["sigma_counts"][199]**2)
    counts_errmin10.append(error)
print(countsmin10)
print(counts_errmin10)
print(len(countsmin10))
# Out:
# [4249.005353261741, 4659.003211885606, 5108.997144593691, 4968.9900067923045, 3858.000356479297, 3422.998215460355, 3031.995716890536, 3013.9999996428064, 883.997501430181, 449.9971445936908, 3342.9928618414206, 1068.9985722968454, 458.9910773017757, 489.9896495986211, 4610.998929133336, 475.9971445936908, 306.9996428063161, 466.00035647929656, 2966.001427345961, 506.997501430181, 316.99214816844005, 602.4572546059737, 1561.156058813489, 3070.003925558586, 449.4469381379947, 1142.155701976999, 2269.997501430181, 62.454407772312905, 163.17317553482246, 377.00428239507653, 720.4515627246205, 1795.1557023341925, 3655.9900064351114]
# [68.3885172643071, 71.32316297162511, 74.41105906282155, 73.46441306429968, 65.46754376820626, 62.05645469324018, 58.82183749513995, 58.66856058157885, 36.221609533106204, 29.631161145839666, 61.40858471382693, 38.69112114446716, 29.782844823295157, 30.298856435571444, 70.98592918134331, 30.066687726630587, 27.110896598747228, 29.899820853008478, 58.25802215418575, 30.577851415179747, 27.294975800524348, 25.562812979201457, 41.489083564136486, 59.143825958039244, 22.370997065191396, 36.088009245572714, 51.9423237559585, 10.651691853244264, 17.98129485338223, 28.372370984736946, 27.77516283712598, 44.21927646345955, 63.90633761683161]
# 33

# %% [markdown]
# #### 21/04

# %%
for key in na22min2:
    indices = np.argsort(na22min2[key]["netcounts"])[-5:][::-1]
    print(indices)
# Out:
# [198 199 197 125 205]
# [198 199 218 197 208]
# [198 199 383 219 221]
# [198 199 321 196 200]
# [198 199 272 204  86]
# [198 199  11 369  52]
# [198 199 197 282 323]
# [198 199 197 228 307]
# [198 199 387 200 216]
# [198 199  72 170 235]
# [198 199 354 255 138]
# [198 199 300  53  68]
# [199 198 183 350 253]
# [198 199 383  92 312]
# [198 199 384  52  60]
# [198 199 200 297 191]
# [198 199  51 212 300]
# [198 199  10  80 221]
# [198 199 269 151 264]
# [198 199 207 322 126]
# [198 199 319 271  56]

# %%
countsmin2 = []
counts_errmin2 = []
for key in na22min2:
    counts = na22min2[key]["netcounts"][198] + na22min2[key]["netcounts"][199]
    countsmin2.append(counts)
    error = np.sqrt(na22min2[key]["sigma_counts"][198]**2 + na22min2[key]["sigma_counts"][199]**2)
    counts_errmin2.append(error)
print(countsmin2)
print(counts_errmin2)
print(len(countsmin2))
# Out:
# [880.0050154190053, 1006.0030095200204, 1011.0147131716808, 1021.0066872253404, 768.0006695283856, 676.9989970505076, 611.0080252747973, 633.0013373779138, 197.00635346846218, 77.0030088484774, 662.0046813263556, 208.0056839400765, 96.99899738627903, 113.99933080738585, 942.0070219895333, 116.01270693692435, 65.00033375687832, 95.00769118214748, 580.0043468979342, 108.00100294949246, 65.00501642631987]
# [30.98370490743239, 32.954422786424125, 33.02984376391409, 33.18111852646462, 29.120416565606256, 27.5136694376474, 26.286573589201986, 26.702009761231214, 16.64293526011081, 12.529723960621576, 27.239505096369857, 16.970227839587963, 13.304210057443198, 13.928436322732848, 31.96851509303555, 13.9990924764003, 12.041566861875918, 13.228175199722829, 25.690295963194345, 13.711236053914421, 12.041178006178363]
# 21

# %% [markdown]
# #### 05/05

# %%
for key in na22m5:
    indices = np.argsort(na22m5[key]["netcounts"])[-5:][::-1]
    print(indices)
# Out:
# [198 199 347 200  35]
# [198 199 200 347 203]
# [198 199 237  37  60]
# [198 199 151 333 321]
# [198 199 197 200 215]
# [198 199 200 197  79]
# [198 199 200  70 159]
# [198 199 200 197  31]
# [198 199 197 188 329]
# [199 198 304 338 256]
# [198 199 197 132 335]

# %%
countsm5 = []
counts_errm5 = []
for key in na22m5:
    counts = na22m5[key]["netcounts"][198] + na22m5[key]["netcounts"][199]
    countsm5.append(counts)
    error = np.sqrt(na22m5[key]["sigma_counts"][198]**2 + na22m5[key]["sigma_counts"][199]**2)
    counts_errm5.append(error)
print(countsm5)
print(counts_errm5)
print(len(countsm5))
# Out:
# [2565.002336446638, 1071.002002477516, 277.9953274410282, 1564.0136840420973, 1090.0066750364879, 1026.0016685083942, 913.002002477516, 1183.0223612217976, 1090.0023361123342, 152.00767627524579, 186.0066750364878]
# [52.583222867767574, 35.651030771705145, 21.863424830896726, 41.99967421050234, 35.91638414947398, 35.01423514816582, 33.36159461244422, 37.18810673530783, 35.916504950090925, 18.761253903690992, 19.646542962378533]
# 11

# %% [markdown]
# ---

# %% [markdown]
# # Table

# %% [markdown]
# #### 17/12

# %% [markdown]
# ##### translational measurements (middle x-axis)
# 1. (4,1): 4.2cm from LaBr3(Ce), 10.2cm from CeBr3
# 2. (4,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3
# 3. (4,7): 10.2cm from LaBr3(Ce), 4.2cm from CeBr3
# 4. (1,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3 BUT 3cm away from middle (Pythagoras: 7.8 cm)
# 5. (7,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3 BUT 3cm away from middle (Pythagoras: 7.8 cm)
# 6. (4,2): 5.2cm from LaBr3(Ce), 9.2cm from CeBr3
# 7. (4,6): 9.2cm from LaBr3(Ce), 5.2cm from CeBr3
# 8. (4,3): 6.2cm from LaBr3(Ce), 8.2cm from CeBr3
# 9. (4,5): 8.2cm from LaBr3(Ce), 6.2cm from CeBr3

# %%
translationalx0 = np.array([4.2, 7.2, 10.2, 7.8, 7.8, 5.2, 9.2, 6.2, 8.2])
translationalx1 = np.array([10.2, 7.2, 4.2, 7.8, 7.8, 9.2, 5.2, 8.2, 6.2])

# %%
time = []
for key in na22d:
    t = na22d[key]["time"]
    time.append(t)
    
table = pd.DataFrame({
    "Pos": na22d.keys(),
    "LaBr3(Ce) [cm]": translationalx0,
    "CeBr3 [cm]": translationalx1,
    "Counts": countsd,
    "Time [s]": time
})
print(table)
# Out:
#   Pos  LaBr3(Ce) [cm]  CeBr3 [cm]       Counts    Time [s]
# 0   1             4.2        10.2  4732.100097  669.836122
# 1   2             7.2         7.2  4324.596201  679.190595
# 2   3            10.2         4.2  3578.976145  707.543323
# 3   4             7.8         7.8   549.717791  652.168636
# 4   5             7.8         7.8   508.022662  643.345508
# 5   6             5.2         9.2  4448.070764  640.547353
# 6   7             9.2         5.2  3492.862438  662.461406
# 7   8             6.2         8.2  4340.209247  640.177641
# 8   9             8.2         6.2  3729.555159  655.272555

# %% [markdown]
# #### 18/03

# %% [markdown]
# ##### turn casing
# 2. (4,4) 0° (casing line -> LaBr3(Ce))
# 3. (4,4) 90°
# 4. (4,4) 180°
# 5. (4,4) 270°

# %%
casing = np.array([0,90,180,270]) #2,3,4,5

# %%
keys = list(na22m.keys())
time = []
for key in na22m:
    t = na22m[key]["time"]
    time.append(t)
    
table = pd.DataFrame({
    "Pos": keys[1:5],
    "Angle [°]": casing,
    "Counts": countsm[1:5],
    "Time [s]": time[1:5]
})
print(table)
# Out:
#   Pos  Angle [°]       Counts    Time [s]
# 0   2          0  2295.317441  299.124460
# 1   3         90  1328.317055  299.125458
# 2   4        180  2257.322461  299.111480
# 3   5        270  1396.322074  299.112480

# %% [markdown]
# ##### rotational measurements
# 6. (7,1) 0° (casing line -> CeBr3)
# 7. 45° (source closest to LaBr3(Ce))
# 8. 90°
# 9. 135° (source in middle (wall side))
# 10. 180°
# 11. 225° (source closest to CeBr3)
# 12. 270°
# 13. 315°

# %%
rotational = np.array([0,45,90,135,180,225,270,315]) #6,7,8,9,10,11,12,13

# %%
table = pd.DataFrame({
    "Pos": keys[5:13],
    "Angle [°]": rotational,
    "Counts": countsm[5:13],
    "Time [s]": time[5:13]
})
print(table)
# Out:
#   Pos  Angle [°]       Counts    Time [s]
# 0   6          0   244.316668  299.126457
# 1   7         45  2357.325163  299.104492
# 2   8         90   207.318985  299.120466
# 3   9        135   143.320530  299.116472
# 4  10        180   240.322460  299.111481
# 5  11        225  1445.317055  299.125457
# 6  12        270   266.325935  299.102496
# 7  13        315   135.313580  299.134442

# %% [markdown]
# ##### translational measurements (middle y-axis)
# 14. (7,4)(bottom middle hole)(casing line -> CeBr3)
# 15. (6,4)
# 16. (5,4)
# 17. (4,4)(middle hole)
# 18. (3,4)
# 19. (2,4)
# 20. (1,4)

# %%
translationaly = np.array([-3,-2,-1,0,1,2,3]) #14,15,16,17,18,19,20

# %%
table = pd.DataFrame({
    "Pos": keys[13:20],
    "Distance [cm]": translationaly,
    "Counts": countsm[13:20],
    "Time [s]": time[13:20]
})
print(table)
# Out:
#   Pos  Distance [cm]       Counts    Time [s]
# 0  14             -3   208.330954  299.089517
# 1  15             -2   503.325549  299.103495
# 2  16             -1  1736.322461  299.111480
# 3  17              0  2140.327866  299.097504
# 4  18              1  1565.319371  299.119468
# 5  19              2   462.318213  299.122462
# 6  20              3   218.320530  299.116473

# %% [markdown]
# #### 01/04

# %% [markdown]
# ##### translational measurements (middle x-axis)
# 1. (4,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3
# 2. (4,3): 6.2cm from LaBr3(Ce), 8.2cm from CeBr3
# 3. (4,2): 5.2cm from LaBr3(Ce), 9.2cm from CeBr3
# 4. (4,1): 4.2cm from LaBr3(Ce), 10.2cm from CeBr3
# 5. (4,5): 8.2cm from LaBr3(Ce), 6.2cm from CeBr3
# 6. (4,6): 9.2cm from LaBr3(Ce), 5.2cm from CeBr3
# 7. (4,7): 10.2cm from LaBr3(Ce), 4.2cm from CeBr3

# %%
translationalx0a1 = np.array([7.2, 6.2, 5.2, 4.2, 8.2, 9.2, 10.2])
translationalx1a1 = np.array([7.2, 8.2, 9.2, 10.2, 6.2, 5.2, 4.2])

# %%
keys = list(na22a1.keys())
time = []
for key in na22a1:
    t = na22a1[key]["time"]
    time.append(t)
    
table = pd.DataFrame({
    "Pos": keys[0:7],
    "LaBr3(Ce) [cm]": translationalx0a1,
    "CeBr3 [cm]": translationalx1a1,
    "Counts": countsa1[0:7],
    "Time [s]": time[0:7]
})
print(table)
# Out:
#   Pos  LaBr3(Ce) [cm]  CeBr3 [cm]       Counts    Time [s]
# 0   1             7.2         7.2  2160.986969  299.122463
# 1   2             6.2         8.2  2481.988598  299.118469
# 2   3             5.2         9.2  2543.997964  299.095507
# 3   4             4.2        10.2  2558.994706  299.103495
# 4   5             8.2         6.2  1948.986155  299.124459
# 5   6             9.2         5.2  1720.985747  299.125457
# 6   7            10.2         4.2  1543.995927  299.100500

# %% [markdown]
# ##### translational measurements (middle y-axis)
# 1. (4,4)(middle hole)(casing line -> CeBr3)
# ---
# 8. (3,4)
# 9. (2,4)
# 10. (1,4)
# 11. (5,4)
# 12. (6,4)
# 13. (7,4)(bottom middle hole)

# %%
translationalya1 = np.array([0,1,2,3,-1,-2,-3])

# %%
indices = [0,7,8,9,10,11,12]
table = pd.DataFrame({
    "Pos": [keys[i] for i in indices],
    "Distance [cm]": translationalya1,
    "Counts": [countsa1[i] for i in indices],
    "Time [s]": [time[i] for i in indices]
})
print(table)
# Out:
#   Pos  Distance [cm]       Counts    Time [s]
# 0   1              0  2160.986969  299.122463
# 1   8              1  1517.997557  299.096506
# 2   9              2   455.997150  299.097503
# 3  10              3   225.987376  299.121464
# 4  11             -1  1621.986969  299.122463
# 5  12             -2   503.992670  299.108486
# 6  13             -3   220.987376  299.121465

# %% [markdown]
# #### 22/04

# %% [markdown]
# ##### translational measurements (middle x-axis)
# 1. (4,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3
# 2. (4,3): 6.2cm from LaBr3(Ce), 8.2cm from CeBr3
# 3. (4,2): 5.2cm from LaBr3(Ce), 9.2cm from CeBr3
# 4. (4,1): 4.2cm from LaBr3(Ce), 10.2cm from CeBr3
# 5. (4,5): 8.2cm from LaBr3(Ce), 6.2cm from CeBr3
# 6. (4,6): 9.2cm from LaBr3(Ce), 5.2cm from CeBr3
# 7. (4,7): 10.2cm from LaBr3(Ce), 4.2cm from CeBr3

# %%
translationalx0min10 = np.array([7.2, 6.2, 5.2, 4.2, 8.2, 9.2, 10.2])
translationalx1min10 = np.array([7.2, 8.2, 9.2, 10.2, 6.2, 5.2, 4.2])

# %%
keys = list(na22min10.keys())
time = []
for key in na22min10:
    t = na22min10[key]["time"]
    time.append(t)
    
table = pd.DataFrame({
    "Pos": keys[0:7],
    "LaBr3(Ce) [cm]": translationalx0min10,
    "CeBr3 [cm]": translationalx1min10,
    "Counts": countsmin10[0:7],
    "Time [s]": time[0:7]
})
print(table)
# Out:
#   Pos  LaBr3(Ce) [cm]  CeBr3 [cm]       Counts    Time [s]
# 0   1             7.2         7.2  4249.005353  599.099750
# 1   2             6.2         8.2  4659.003212  599.105745
# 2   3             5.2         9.2  5108.997145  599.122731
# 3   4             4.2        10.2  4968.990007  599.142714
# 4   5             8.2         6.2  3858.000356  599.113739
# 5   6             9.2         5.2  3422.998215  599.119733
# 6   7            10.2         4.2  3031.995717  599.126728

# %% [markdown]
# ##### translational measurements (middle y-axis)
# 1. (4,4)(middle hole)(casing line -> CeBr3)
# ---
# 8. (3,4)
# 9. (2,4)
# 10. (1,4)
# 11. (5,4)
# 12. (6,4)
# 13. (7,4)(bottom middle hole)

# %%
translationalymin10 = np.array([0,1,2,3,-1,-2,-3])

# %%
indices = [0,7,8,9,10,11,12]
table = pd.DataFrame({
    "Pos": [keys[i] for i in indices],
    "Distance [cm]": translationalymin10,
    "Counts": [countsmin10[i] for i in indices],
    "Time [s]": [time[i] for i in indices]
})
print(table)
# Out:
#   Pos  Distance [cm]       Counts    Time [s]
# 0   1              0  4249.005353  599.099750
# 1   8              1  3014.000000  599.114738
# 2   9              2   883.997501  599.121732
# 3  10              3   449.997145  599.122731
# 4  11             -1  3342.992862  599.134721
# 5  12             -2  1068.998572  599.118734
# 6  13             -3   458.991077  599.139717

# %% [markdown]
# ##### rotational measurements
# 14. (7,1) 0°
# 15. 45° (source closest to LaBr3(Ce))
# 16. 90°
# 17. 135° (source in middle (wall side))
# 18. 180°
# 19. 225° (source closest to CeBr3)
# 20. 270°
# 21. 315°

# %%
rotationalmin10 = np.array([0,45,90,135,180,225,270,315])

# %%
table = pd.DataFrame({
    "Pos": keys[13:21],
    "Angle [°]": rotationalmin10,
    "Counts": countsmin10[13:21],
    "Time [s]": time[13:21]
})
print(table)
# Out:
#   Pos  Angle [°]       Counts    Time [s]
# 0  14          0   489.989650  599.143714
# 1  15         45  4610.998929  599.117735
# 2  16         90   475.997145  599.122731
# 3  17        135   306.999643  599.115737
# 4  18        180   466.000356  599.113739
# 5  19        225  2966.001427  599.110741
# 6  20        270   506.997501  599.121732
# 7  21        315   316.992148  599.136719

# %% [markdown]
# #### 21/04

# %% [markdown]
# ##### translational measurements (middle x-axis)
# 1. (4,4): 7.2cm from LaBr3(Ce), 7.2cm from CeBr3
# 2. (4,3): 6.2cm from LaBr3(Ce), 8.2cm from CeBr3
# 3. (4,2): 5.2cm from LaBr3(Ce), 9.2cm from CeBr3
# 4. (4,1): 4.2cm from LaBr3(Ce), 10.2cm from CeBr3
# 5. (4,5): 8.2cm from LaBr3(Ce), 6.2cm from CeBr3
# 6. (4,6): 9.2cm from LaBr3(Ce), 5.2cm from CeBr3
# 7. (4,7): 10.2cm from LaBr3(Ce), 4.2cm from CeBr3

# %%
translationalx0min2 = np.array([7.2, 6.2, 5.2, 4.2, 8.2, 9.2, 10.2])
translationalx1min2 = np.array([7.2, 8.2, 9.2, 10.2, 6.2, 5.2, 4.2])

# %%
keys = list(na22min2.keys())
time = []
for key in na22min2:
    t = na22min2[key]["time"]
    time.append(t)
    
table = pd.DataFrame({
    "Pos": keys[0:7],
    "LaBr3(Ce) [cm]": translationalx0min2,
    "CeBr3 [cm]": translationalx1min2,
    "Counts": countsmin2[0:7],
    "Time [s]": time[0:7]
})
print(table)
# Out:
#   Pos  LaBr3(Ce) [cm]  CeBr3 [cm]       Counts    Time [s]
# 0   1             7.2         7.2   880.005015  119.113694
# 1   2             6.2         8.2  1006.003010  119.119668
# 2   3             5.2         9.2  1011.014713  119.084812
# 3   4             4.2        10.2  1021.006687  119.108715
# 4   5             8.2         6.2   768.000670  119.126637
# 5   6             9.2         5.2   676.998997  119.131618
# 6   7            10.2         4.2   611.008025  119.104730

# %% [markdown]
# ##### translational measurements (middle y-axis)
# 1. (4,4)(middle hole)(casing line -> CeBr3)
# ---
# 8. (3,4)
# 9. (2,4)
# 10. (1,4)
# 11. (5,4)
# 12. (6,4)
# 13. (7,4)(bottom middle hole)

# %%
translationalymin2 = np.array([0,1,2,3,-1,-2,-3])

# %%
indices = [0,7,8,9,10,11,12]
table = pd.DataFrame({
    "Pos": [keys[i] for i in indices],
    "Distance [cm]": translationalymin2,
    "Counts": [countsmin2[i] for i in indices],
    "Time [s]": [time[i] for i in indices]
})
print(table)
# Out:
#   Pos  Distance [cm]      Counts    Time [s]
# 0   1              0  880.005015  119.113694
# 1   8              1  633.001337  119.124648
# 2   9              2  197.006353  119.109709
# 3  10              3   77.003009  119.119670
# 4  11             -1  662.004681  119.114689
# 5  12             -2  208.005684  119.111703
# 6  13             -3   96.998997  119.131617

# %% [markdown]
# ##### rotational measurements
# 14. (7,1) 0°
# 15. 45° (source closest to LaBr3(Ce))
# 16. 90°
# 17. 135° (source in middle (wall side))
# 18. 180°
# 19. 225° (source closest to CeBr3)
# 20. 270°
# 21. 315°

# %%
rotationalmin2 = np.array([0,45,90,135,180,225,270,315])

# %%
table = pd.DataFrame({
    "Pos": keys[13:21],
    "Angle [°]": rotationalmin2,
    "Counts": countsmin2[13:21],
    "Time [s]": time[13:21]
})
print(table)
# Out:
#   Pos  Angle [°]      Counts    Time [s]
# 0  14          0  113.999331  119.130624
# 1  15         45  942.007022  119.107718
# 2  16         90  116.012707  119.090787
# 3  17        135   65.000334  119.127637
# 4  18        180   95.007691  119.105725
# 5  19        225  580.004347  119.115685
# 6  20        270  108.001003  119.125644
# 7  21        315   65.005016  119.113691

# %% [markdown]
# #### 05/05

# %% [markdown]
# ##### rotational measurements
# 6. (7,1) 22.5°
# 7. 67.5°
# 8. 202.5°
# 9. 247.5°

# %%
rotationalm5 = np.array([22.5,67.5,202.5,247.5])

# %%
keys = list(na22m5.keys())
time = []
for key in na22m5:
    t = na22m5[key]["time"]
    time.append(t)
table = pd.DataFrame({
    "Pos": keys[5:9],
    "Angle [°]": rotationalm5,
    "Counts": countsm5[5:9],
    "Time [s]": time[5:9]
})
print(table)
# Out:
#   Pos  Angle [°]       Counts    Time [s]
# 0   6       22.5  1026.001669  299.124460
# 1   7       67.5   913.002002  299.123461
# 2   8      202.5  1183.022361  299.062562
# 3   9      247.5  1090.002336  299.122463

# %% [markdown]
# ---

# %% [markdown]
# # Count rate

# %% [markdown]
# #### 17/12

# %%
t = []
for key in na22d:
    time = na22d[key]["time"]
    t.append(time)

# %%
time = np.array(t)
rated = countsd/time
rate_errd = counts_errd/time
print(rated)
print(rate_errd)
print(len(rated))
# Out:
# [7.06456392 6.36727928 5.05831379 0.84290743 0.78965759 6.94417164
#  5.27255234 6.77969515 5.69160898]
# [0.10830265 0.10271252 0.09111575 0.04990368 0.04932757 0.10976942
#  0.09564527 0.1086232  0.09940348]
# 9

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalx0[[0,1,2,5,6,7,8]], rated[[0,1,2,5,6,7,8]], xerr=0.1, yerr=rate_errd[[0,1,2,5,6,7,8]], fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
plt.xlabel("Distance from LaBr3(Ce) (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### 18/03

# %%
t = []
for key in na22m:
    time = na22m[key]["time"]
    t.append(time)

# %%
time = np.array(t)
ratem = countsm/time
rate_errm = counts_errm/time
print(ratem)
print(rate_errm)
print(len(ratem))
# Out:
# [7.97162949 7.67345285 4.44066869 7.54675969 4.66821737 0.81676717
#  7.88127636 0.69309529 0.47914623 0.80345448 4.83180893 0.89041696
#  0.45235039 0.69655051 1.68278057 5.8049342  7.15595362 5.23309092
#  1.54558173 0.72988467]
# [0.17088526 0.16793688 0.13189107 0.16667453 0.1347468  0.07266534
#  0.16999827 0.06976303 0.06443336 0.07235983 0.13675842 0.07434251
#  0.06373309 0.06984845 0.09042081 0.14817917 0.16271147 0.14157952
#  0.0878454  0.07063938]
# 20

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(rotational, ratem[5:13], xerr=2.5, yerr=rate_errm[5:13], fmt='o', color='#4CAF50', label='rotational data 5 min with casing', capsize=4)
plt.xlabel("Angle (°)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.errorbar([0], ratem[1], xerr=0.1, yerr=rate_errm[1], fmt='o', label='casing turned 0°', capsize=4)
plt.errorbar([0], ratem[2], xerr=0.1, yerr=rate_errm[2], fmt='o', label='casing turned 90°', capsize=4)
plt.errorbar([0], ratem[3], xerr=0.1, yerr=rate_errm[3], fmt='o', label='casing turned 180°', capsize=4)
plt.errorbar([0], ratem[4], xerr=0.1, yerr=rate_errm[4], fmt='o', label='casing turned 270°', capsize=4)
plt.errorbar(translationaly, ratem[13:20], xerr=0.1, yerr=rate_errm[13:20], fmt='o', label='translational data 5 min with casing', capsize=4)
plt.xlabel("Distance from middle (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### 01/04

# %%
t = []
for key in na22a1:
    time = na22a1[key]["time"]
    t.append(time)

# %%
time = np.array(t)
ratea1 = countsa1/time
rate_erra1 = counts_erra1/time
print(ratea1)
print(rate_erra1)
print(len(ratea1))
# Out:
# [7.22442222 8.29767753 8.50563751 8.55554933 6.5156362  5.75339112
#  5.16213088 5.0752768  1.52457692 0.75550371 5.42248467 1.68498285
#  0.73878809 5.79691325]
# [0.16394979 0.17455067 0.17653744 0.17700718 0.15655615 0.14819415
#  0.14137337 0.14034347 0.08845818 0.07247914 0.14441418 0.09143792
#  0.0720926  0.14868494]
# 14

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalx0a1, ratea1[0:7], xerr=0.1, yerr=rate_erra1[0:7], fmt='o', color='#4CAF50', label='translational data 5 min with casing', capsize=4)
plt.xlabel("Distance from LaBr3(Ce) (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalya1, ratea1[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_erra1[[0,7,8,9,10,11,12]], color='#4CAF50', fmt='o', label='translational data 5 min with casing', capsize=4)
plt.xlabel("Distance from middle (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### 22/04

# %%
t = []
for key in na22min10:
    time = na22min10[key]["time"]
    t.append(time)

# %%
time = np.array(t)
ratemin10 = countsmin10/time
rate_errmin10 = counts_errmin10/time
print(ratemin10)
print(rate_errmin10)
print(len(ratemin10))
# Out:
# [7.09231702 7.77659579 8.52746337 8.29349985 6.43951241 5.71337919
#  5.0606918  5.03075589 1.47548896 0.75109343 5.57970143 1.784285
#  0.76608354 0.81781656 7.6963152  0.79449021 0.51242126 0.77781617
#  4.9506731  0.84623454 0.52908149 5.05829899 5.21915494 5.1243277
#  3.77269227 3.81836757 3.78887525 0.52433916 0.54559731 0.62928151
#  6.0481833  6.00142724 6.10203532]
# [0.11415214 0.11904937 0.12420003 0.12261588 0.10927398 0.10357939
#  0.09817929 0.09792542 0.06045785 0.04945758 0.10249545 0.06458006
#  0.04970935 0.05057027 0.11848411 0.05018452 0.04525152 0.04990675
#  0.09724082 0.05103779 0.04555717 0.21462826 0.13870359 0.09872051
#  0.18778388 0.12064667 0.08669745 0.08942682 0.06012352 0.04735811
#  0.2331722  0.1478305  0.10666296]
# 33

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalx0min10, ratemin10[0:7], xerr=0.1, yerr=rate_errmin10[0:7], fmt='o', color='#4CAF50', label='translational data 10 min with casing', capsize=4)
plt.xlabel("Distance from LaBr3(Ce) (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalymin10, ratemin10[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_errmin10[[0,7,8,9,10,11,12]], fmt='o', color='#4CAF50', label='translational data 10 min with casing', capsize=4)
plt.xlabel("Distance from middle (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(rotationalmin10, ratemin10[13:21], xerr=2.5, yerr=rate_errmin10[13:21], fmt='o', color='#4CAF50', label='rotational data 10 min with casing', capsize=4)
plt.xlabel("Angle (°)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### 21/04

# %%
t = []
for key in na22min2:
    time = na22min2[key]["time"]
    t.append(time)

# %%
time = np.array(t)
ratemin2 = countsmin2/time
rate_errmin2 = counts_errmin2/time
print(ratemin2)
print(rate_errmin2)
print(len(ratemin2))
# Out:
# [7.3879416  8.44531408 8.48987118 8.57205694 6.44692647 5.68278185
#  5.13000638 5.31377299 1.65399072 0.64643403 5.55770818 1.7463077
#  0.81421708 0.95692717 7.90886634 0.9741535  0.54563605 0.79767527
#  4.8692525  0.90661422 0.54573925]
# [0.26011875 0.27664972 0.27736403 0.27857843 0.24444925 0.23095187
#  0.22070134 0.22415185 0.13972778 0.10518602 0.22868301 0.14247322
#  0.11167657 0.11691735 0.26840003 0.11754975 0.10108122 0.11106246
#  0.21567517 0.11509895 0.10108979]
# 21

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalx0min2, ratemin2[0:7], xerr=0.1, yerr=rate_errmin2[0:7], fmt='o', color='#4CAF50', label='translational data 2 min with casing', capsize=4)
plt.xlabel("Distance from LaBr3(Ce) (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalx0min2, ratemin2[0:7], xerr=0.1, yerr=rate_errmin2[0:7], fmt='o', label='translational data 2 min with casing', capsize=4)
plt.errorbar(translationalx0a1, ratea1[0:7], xerr=0.1, yerr=rate_erra1[0:7], fmt='o', label='translational data 5 min with casing', capsize=4)
plt.errorbar(translationalx0min10, ratemin10[0:7], xerr=0.1, yerr=rate_errmin10[0:7], fmt='o', label='translational data 10 min with casing', capsize=4)
plt.errorbar(translationalx0[[0,1,2,5,6,7,8]], rated[[0,1,2,5,6,7,8]], xerr=0.1, yerr=rate_errd[[0,1,2,5,6,7,8]], fmt='o', label='translational data 10 min without casing', capsize=4)
plt.xlabel("Distance from LaBr3(Ce) (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalymin2, ratemin2[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_errmin2[[0,7,8,9,10,11,12]], fmt='o', color='#4CAF50', label='translational data 2 min with casing', capsize=4)
plt.xlabel("Distance from middle (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(translationalymin2, ratemin2[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_errmin2[[0,7,8,9,10,11,12]], fmt='o', label='translational data 2 min with casing', capsize=4)
plt.errorbar(translationaly, ratem[13:20], xerr=0.1, yerr=rate_errm[13:20], fmt='o', label='translational data 5 min with casing', capsize=4)
plt.errorbar(translationalya1, ratea1[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_erra1[[0,7,8,9,10,11,12]], fmt='o', label='translational data 5 min with casing', capsize=4)
plt.errorbar(translationalymin10, ratemin10[[0,7,8,9,10,11,12]], xerr=0.1, yerr=rate_errmin10[[0,7,8,9,10,11,12]], fmt='o', label='translational data 10 min with casing', capsize=4)
plt.errorbar([3,-3], rated[3:5], xerr=0.1, yerr=rate_errd[3:5], fmt='o', label='translational data 10 min without casing', capsize=4)
plt.xlabel("Distance from middle (cm)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(rotationalmin2, ratemin2[13:21], xerr=2.5, yerr=rate_errmin2[13:21], fmt='o', color='#4CAF50', label='rotational data 2 min with casing', capsize=4)
plt.xlabel("Angle (°)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(rotationalmin2, ratemin2[13:21], xerr=2.5, yerr=rate_errmin2[13:21], fmt='o', label='rotational data 2 min with casing', capsize=4)
plt.errorbar(rotational, ratem[5:13], xerr=2.5, yerr=rate_errm[5:13], fmt='o', label='rotational data 5 min with casing', capsize=4)
plt.errorbar(rotationalmin10, ratemin10[13:21], xerr=2.5, yerr=rate_errmin10[13:21], fmt='o', label='rotational data 10 min with casing', capsize=4)
plt.xlabel("Angle (°)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### 05/05

# %%
t = []
for key in na22m5:
    time = na22m5[key]["time"]
    t.append(time)

# %%
time = np.array(t)
ratem5 = countsm5/time
rate_errm5 = counts_errm5/time
print(ratem5)
print(rate_errm5)
print(len(ratem5))
# Out:
# [8.57509102 3.58046807 0.92930448 5.22926689 3.6441729  3.43001595
#  3.05225809 3.95576883 3.64400027 0.50820588 0.6218682 ]
# [0.17579162 0.119185   0.07308676 0.14042557 0.12007772 0.11705574
#  0.11153119 0.12434892 0.12007291 0.06272433 0.06568345]
# 11

# %%
fig = plt.figure(figsize=(9,6))
plt.errorbar(rotational, ratem[5:13], xerr=2.5, yerr=rate_errm[5:13], fmt='o', color='#4CAF50', label='rotational data 5 min with casing', capsize=4)
plt.errorbar(rotationalm5, ratem5[5:9], xerr=2.5, yerr=rate_errm5[5:9], fmt='o', color='#4CAF50', capsize=4)
plt.xlabel("Angle (°)")
plt.ylabel("Count rate (Hz)")
plt.title("Count rate")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Translational fit

# %%
def omega_rect(d, p, q, a):
    corners = [(a - p, a - q),
               (a + p, a - q),
               (a - p, a + q),
               (a + p, a + q)]
    omega = 0.0
    for (u, v) in corners:
        R = np.sqrt(d**2 + u**2 + v**2)
        omega += np.arctan2(u * v, d * R)   # arctan(uv / dR)
    return omega

def coinc_trans(x, y, A, s1, s2, B):
    
    #LaBr3(Ce)
    r = 3.81/2 
    x_cil = s1 - x + 0.26
    y_cil = y
    d_cil = np.sign(x_cil)*np.sqrt(x_cil**2 + y_cil**2)
    
    omega_cil = 2*np.pi*(1-d_cil/(np.sqrt(d_cil**2+r**2)))
    geom_factor_cil = omega_cil/(4*np.pi)
    
    cos_cil = x_cil/d_cil
    
    #CeBr3 
    a = 4.8/2
    b = 4.8/2
    x_sq = s2 + x
    y_sq = y
    
    omega_sq = omega_rect(x_sq, 0.0, y_sq, a)
    geom_factor_sq = omega_sq/(4*np.pi)

    return A * geom_factor_sq * geom_factor_cil * cos_cil + B

# %%
def coinc_trans_x(x, A, s1, s2, B):
    return coinc_trans(x, 0, A, s1, s2, B)

# %%
def coinc_trans_y(x, A, s1, s2, B):
    return coinc_trans(7.2, x, A, s1, s2, B)

# %%
def coinc_rot(x, A, s1, s2, B):
    d_x = np.sqrt(18)*np.sin(np.radians(x+45))
    d_y = np.sqrt(18)*np.cos(np.radians(x+45-180))
    return coinc_trans(d_x, d_y, A, s1, s2, B)

# %% [markdown]
# #### 17/12

# %%
x = translationalx0[[0,1,2,5,6,7,8]] - 7.2
y = rated[[0,1,2,5,6,7,8]]
yerr=rate_errd[[0,1,2,5,6,7,8]]

# Fit the resolution
p0 = [543,-3,10,0]
popt, pcov = curve_fit(
    coinc_trans_x,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=20000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_trans_x(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[2]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_x(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from LaBr3(Ce) (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 1.3108e+03 ± 2.6810e+03
# s1 = -4.6443e+00 ± 1.0100e+00
# s2 = 1.9993e+01 ± 1.4290e+01
# B = 5.6032e-01 ± 1.4290e+01
# Reduced chi²: 1.923
# P-value: 0.1234

# %% [markdown]
# #### 01/04

# %%
x = translationalx0a1 - 7.2
y = ratea1[0:7]
yerr=rate_erra1[0:7]

# Fit the resolution
p0 = [543,-3,10,0]
popt, pcov = curve_fit(
    coinc_trans_x,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=20000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_trans_x(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[2]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_x(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from LaBr3(Ce) (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.4913e+03 ± 4.7698e+03
# s1 = -4.6013e+00 ± 9.1571e-01
# s2 = 2.0636e+01 ± 1.3773e+01
# B = -2.8345e+00 ± 1.3773e+01
# Reduced chi²: 0.919
# P-value: 0.4306

# %% [markdown]
# #### 22/04

# %%
x = translationalx0min10 - 7.2
y = ratemin10[0:7]
yerr=rate_errmin10[0:7]

# Fit the resolution
p0 = [543,-3,10,0]
popt, pcov = curve_fit(
    coinc_trans_x,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=20000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_trans_x(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[2]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_x(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from LaBr3(Ce) (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 1.5521e+03 ± 1.9828e+03
# s1 = -4.4172e+00 ± 6.1597e-01
# s2 = 1.7813e+01 ± 8.0265e+00
# B = -1.2893e+00 ± 8.0265e+00
# Reduced chi²: 0.514
# P-value: 0.6728

# %%
x = translationalx0min2 - 7.2
y = ratemin2[0:7]
yerr=rate_errmin2[0:7]

# Fit the resolution
p0 = [543,-3,10,0]
popt, pcov = curve_fit(
    coinc_trans_x,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=20000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_trans_x(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[2]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_x(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from LaBr3(Ce) (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 3.2862e+03 ± 9.8436e+03
# s1 = -4.6378e+00 ± 1.3984e+00
# s2 = 2.2272e+01 ± 2.3122e+01
# B = -4.1459e+00 ± 2.3122e+01
# Reduced chi²: 0.765
# P-value: 0.5136

# %%
plt.errorbar(translationalx0min2, ratemin2[0:7], xerr=0.1, yerr=rate_errmin2[0:7], fmt='o', label='translational data 2 min with casing', capsize=4)
plt.errorbar(translationalx0a1, ratea1[0:7], xerr=0.1, yerr=rate_erra1[0:7], fmt='o', label='translational data 5 min with casing', capsize=4)
plt.errorbar(translationalx0min10, ratemin10[0:7], xerr=0.1, yerr=rate_errmin10[0:7], fmt='o', label='translational data 10 min with casing', capsize=4)

x = translationalx0[[0,1,2,5,6,7,8]] - 7.2
y = rated[[0,1,2,5,6,7,8]]
yerr=rate_errd[[0,1,2,5,6,7,8]]

# Fit the resolution
p0 = [543,-3,10,0]
popt, pcov = curve_fit(
    coinc_trans_x,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=20000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_trans_x(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[2]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min without casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_x(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from LaBr3(Ce) (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 1.7599e+03 ± 2.4298e+02
# s1 = -4.7867e+00 ± 2.4841e-01
# s2 = 2.2147e+01 ± 1.6240e+00
# Reduced chi²: 1.448
# P-value: 0.2154

# %% [markdown]
# ---

# %% [markdown]
# #### 18/03

# %%
x = translationaly
y = ratem[13:20]
yerr=rate_errm[13:20]

# Fit the resolution
p0 = [9.0969e+02,7.2, 7.2]
popt, pcov = curve_fit(
    coinc_trans_y,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coincy, s1_coincy, s2_coincy = popt

# Residuals
residuals = y - coinc_trans_y(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coincy:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coincy:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coincy:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 5 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_y(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from middle (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.0953e+02 ± 3.7270e+01
# s1 = 8.5321e+00 ± 7.1398e-02
# s2 = -5.2145e+00 ± 4.2655e-01
# Reduced chi²: 18.026
# P-value: 0.0000

# %% [markdown]
# #### 01/04

# %%
x = translationalya1
y = ratea1[[0,7,8,9,10,11,12]]
yerr=rate_erra1[[0,7,8,9,10,11,12]]

# Fit the resolution
p0 = [9.0969e+02,7.2, 7.2]
popt, pcov = curve_fit(
    coinc_trans_y,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coincy, s1_coincy, s2_coincy = popt

# Residuals
residuals = y - coinc_trans_y(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coincy:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coincy:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coincy:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 5 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_y(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from middle (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.6096e+02 ± 6.5524e+01
# s1 = 8.4556e+00 ± 8.3968e-02
# s2 = -4.6183e+00 ± 6.3954e-01
# Reduced chi²: 11.887
# P-value: 0.0000

# %% [markdown]
# #### 22/04

# %%
x = translationalymin10
y = ratemin10[[0,7,8,9,10,11,12]]
yerr=rate_errmin10[[0,7,8,9,10,11,12]]

# Fit the resolution
p0 = [9.0969e+02,7.2, 7.2]
popt, pcov = curve_fit(
    coinc_trans_y,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coincy, s1_coincy, s2_coincy = popt

# Residuals
residuals = y - coinc_trans_y(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coincy:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coincy:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coincy:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 10 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_y(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from middle (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.5856e+02 ± 4.3245e+01
# s1 = 8.4990e+00 ± 6.0166e-02
# s2 = -4.6754e+00 ± 4.2722e-01
# Reduced chi²: 32.106
# P-value: 0.0000

# %%
x = translationalymin2
y = ratemin2[[0,7,8,9,10,11,12]]
yerr=rate_errmin2[[0,7,8,9,10,11,12]]

# Fit the resolution
p0 = [9.0969e+02,7.2, 7.2]
popt, pcov = curve_fit(
    coinc_trans_y,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coincy, s1_coincy, s2_coincy = popt

# Residuals
residuals = y - coinc_trans_y(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coincy:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coincy:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coincy:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =0.1, yerr=yerr, fmt='o', color='#4CAF50', label='translational data 2 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_trans_y(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Distance from middle (cm)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.3874e+02 ± 7.5405e+01
# s1 = 8.5071e+00 ± 1.2099e-01
# s2 = -4.9382e+00 ± 7.8324e-01
# Reduced chi²: 4.443
# P-value: 0.0014

# %% [markdown]
# ---

# %% [markdown]
# # Rotational fit

# %%
x = np.append(rotational,rotationalm5)
y = np.append(ratem[5:13],ratem5[5:9])
yerr=np.append(rate_errm[5:13],rate_errm5[5:9])

# Fit the resolution
p0 = [500,7.2,7.2, 0]
popt, pcov = curve_fit(
    coinc_rot,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc, B_coinc = popt

# Residuals
residuals = y - coinc_rot(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")
print(f"B = {B_coinc:.4e} ± {perr[3]:.4e}")


# --- Main plot ---
x_plot = np.linspace(min(x), max(x), 500)

ax_main.errorbar(x, y, xerr =2.5, yerr=yerr, fmt='o', color='#4CAF50', label='rotational data 5 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_rot(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Angle (°)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 2.7050e+03 ± 1.7017e+02
# s1 = 5.5130e+00 ± 7.2404e-02
# s2 = 5.7952e+00 ± 9.7194e-02
# B = -7.8985e-01 ± 6.8275e-02
# Reduced chi²: 14.890
# P-value: 0.0000

# %%
x = rotationalmin10
y = ratemin10[13:21]
yerr=rate_errmin10[13:21]

# Fit the resolution
p0 = [500,7.2,7.2]
popt, pcov = curve_fit(
    coinc_rot,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc = popt

# Residuals
residuals = y - coinc_rot(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =2.5, yerr=yerr, fmt='o', color='#4CAF50', label='rotational data 10 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_rot(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Angle (°)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")

# %%
x = rotationalmin2
y = ratemin2[13:21]
yerr=rate_errmin2[13:21]

# Fit the resolution
p0 = [500,7.2,7.2]
popt, pcov = curve_fit(
    coinc_rot,
    x,
    y,
    p0=p0,
    sigma=yerr,
    absolute_sigma=True, 
    maxfev=10000
)
perr = np.sqrt(np.diag(pcov))
A_coinc, s1_coinc, s2_coinc = popt

# Residuals
residuals = y - coinc_rot(x, *popt)

# --- Compute reduced chi² and p-value ---
chi2_val = np.sum((residuals / yerr)**2)
ndof = len(x) - len(popt)
chi2_red = chi2_val / ndof
p_value = 1 - chi2.cdf(chi2_val, ndof)

# --- Plotting ---
fig, (ax_main, ax_resid) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios':[3,1]}, figsize=(8,6))

print(f"A = {A_coinc:.4e} ± {perr[0]:.4e}")
print(f"s1 = {s1_coinc:.4e} ± {perr[1]:.4e}")
print(f"s2 = {s2_coinc:.4e} ± {perr[2]:.4e}")

# --- Main plot ---
x_plot = np.linspace(min(x)*1.1, max(x)*1.1, 500)

ax_main.errorbar(x, y, xerr =2.5, yerr=yerr, fmt='o', color='#4CAF50', label='rotational data 2 min with casing', capsize=4)
ax_main.plot(x_plot, coinc_rot(x_plot, *popt), 'k--', label=r'model: $A \cdot \Omega_1 \cdot \Omega_2$')
ax_main.set_ylabel("Count rate (Hz)")
ax_main.set_title("Count rate")
ax_main.legend()
ax_main.grid(True, alpha=0.3)

ax_resid.errorbar(x, residuals, yerr=yerr, fmt='o', color='#4CAF50', capsize=4)
ax_resid.axhline(0, color='black', linestyle='--')
ax_resid.set_xlabel("Angle (°)")
ax_resid.set_ylabel("Count rate (Hz)")
ax_resid.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Reduced chi²: {chi2_red:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# A = 8.1872e+02 ± 4.0008e+01
# s1 = 4.5691e+00 ± 9.8594e-02
# s2 = 3.6909e+00 ± 1.1383e-01
# Reduced chi²: 2.242
# P-value: 0.0474

# %% [markdown]
# ---

# %% [markdown]
# # Find positions

# %% [markdown]
# #### translational x-axis
# ##### 22/04
# - 32: diagonal on x-axis by rotating 45°, third hole from the CeBr detector
#
# ##### 05/05
# - 1: diagonal on x-axis by rotating 45°, second hole from the LaBr3Ce detector
# - 4: diagonal on x-axis by rotating 45°, second hole from the CeBr3 detector
# ----------------------------------------------------------------------------------
# #### translational y-axis
# ##### 05/05
# - 2: diagonal on x-axis by rotating 45°, 3th hole from the wall (y-axis)
# - 3: diagonal on x-axis by rotating 45°, 6th hole from the wall (y-axis)
# - 5: diagonal on x-axis by rotating 45°, 5th hole from the wall (y-axis)
# ----------------------------------------------------------------------------------
# #### rotational
# ##### 22/04
# - 29: 292.5°
#
# ##### 05:05
# - 10: 337.5°
# - 11: 112.5°

# %% [markdown]
# ## translational x-axis

# %%
def find_transx(y_target, A, s1, s2, x_min, x_max):
    def f(x):
        return coinc_trans_x(x, A, s1, s2) - y_target

    sol = root_scalar(f, bracket=[x_min, x_max], method='brentq')
    return sol.root

def find_bracketsx(y_target, A, s1, s2, x_vals):
    f_vals = coinc_trans_x(x_vals, A, s1, s2) - y_target
    brackets = []

    for i in range(len(x_vals)-1):
        if f_vals[i] * f_vals[i+1] < 0:
            brackets.append((x_vals[i], x_vals[i+1]))

    return brackets

# %%
A_fitx1 = 8.7404e+02 
s1_fitx1 = -4.1091e+00 
s2_fitx1 = 1.4262e+01 
A_fitx = 9.0999e+02
s1_fitx = -4.1663e+00
s2_fitx = 1.4744e+01

# %%
x_vals = np.linspace(-5, 5, 1000)
brackets = find_bracketsx(ratem5[0], A_fitx1, s1_fitx1, s2_fitx1, x_vals)

print(brackets)
# Out:
# [(-2.9279279279279278, -2.9179179179179178), (-1.7167167167167166, -1.7067067067067065)]

# %%
print(-np.sqrt(2**2 + 2**2))
x = find_transx(y_target=ratem5[0], A=A_fitx1, s1=s1_fitx1, s2=s2_fitx1, x_min=-2.9279279279279278, x_max=-2.9179179179179178)
print(x)
# Out:
# -2.8284271247461903
# -2.9231815740874234

# %%
x_vals = np.linspace(-5, 5, 1000)
brackets = find_bracketsx(ratem5[3], A_fitx, s1_fitx, s2_fitx, x_vals)

print(brackets)
# Out:
# [(-4.52952952952953, -4.51951951951952), (2.7777777777777777, 2.7877877877877877)]

# %%
print(np.sqrt(2**2 + 2**2))
x = find_transx(y_target=ratem5[3], A=A_fitx, s1=s1_fitx, s2=s2_fitx, x_min=2.7777777777777777, x_max=2.7877877877877877)
print(x)
# Out:
# 2.8284271247461903
# 2.7835609385511573

# %%
x_vals = np.linspace(-5, 5, 1000)
brackets = find_bracketsx(ratemin10[31], A_fitx, s1_fitx, s2_fitx, x_vals)

print(brackets)
# Out:
# [(-4.2192192192192195, -4.2092092092092095), (1.5165165165165169, 1.5265265265265269)]

# %%
print(np.sqrt(1**2 + 1**2))
x = find_transx(y_target=ratemin10[31], A=A_fitx, s1=s1_fitx, s2=s2_fitx, x_min=1.5165165165165169, x_max=1.5265265265265269)
print(x)
# Out:
# 1.4142135623730951
# 1.516702600082215

# %% [markdown]
# ## translational y-axis

# %%
def find_transy(y_target, A, s1, s2, x_min, x_max):
    def f(x):
        return coinc_trans_y(x, A, s1, s2) - y_target

    sol = root_scalar(f, bracket=[x_min, x_max], method='brentq')
    return sol.root

def find_bracketsy(y_target, A, s1, s2, x_vals):
    f_vals = coinc_trans_y(x_vals, A, s1, s2) - y_target
    brackets = []

    for i in range(len(x_vals)-1):
        if f_vals[i] * f_vals[i+1] < 0:
            brackets.append((x_vals[i], x_vals[i+1]))

    return brackets

# %%
A_fity = 2.6096e+02
s1_fity = 8.4556e+00
s2_fity = -4.6183e+00

# %%
x_vals = np.linspace(-4, 4, 1000)
brackets = find_bracketsy(ratem5[1], A_fity, s1_fity, s2_fity, x_vals)

print(brackets)
# Out:
# [(-1.3573573573573574, -1.3493493493493496), (1.3493493493493496, 1.3573573573573574)]

# %%
print(np.sqrt(1**2+1**2))
x = find_transy(y_target=ratem5[1], A=A_fity, s1=s1_fity, s2=s2_fity, x_min=1.3493493493493496, x_max=1.3573573573573574)
print(x)
# Out:
# 1.4142135623730951
# 1.3529120058615784

# %%
x_vals = np.linspace(-4, 4, 1000)
brackets = find_bracketsy(ratem5[2], A_fity, s1_fity, s2_fity, x_vals)

print(brackets)
# Out:
# [(-2.6386386386386387, -2.6306306306306304), (2.6306306306306304, 2.6386386386386382)]

# %%
print(np.sqrt(2**2+2**2))
x = find_transy(y_target=ratem5[2], A=A_fity, s1=s1_fity, s2=s2_fity, x_min=2.6306306306306304, x_max=2.6386386386386382)
print(x)
# Out:
# 2.8284271247461903
# 2.6366712547847366

# %%
x_vals = np.linspace(-4, 4, 1000)
brackets = find_bracketsy(ratem5[4], A_fity, s1_fity, s2_fity, x_vals)

print(brackets)
# Out:
# [(-1.3413413413413413, -1.3333333333333335), (1.333333333333333, 1.3413413413413409)]

# %%
print(np.sqrt(1**2+1**2))
x = find_transy(y_target=ratem5[4], A=A_fity, s1=s1_fity, s2=s2_fity, x_min=1.333333333333333, x_max=1.3413413413413409)
print(x)
# Out:
# 1.4142135623730951
# 1.3338375313299045

# %% [markdown]
# ## rotational

# %%
def find_rot(y_target, A, s1, s2, B, x_min, x_max):
    def f(x):
        return coinc_rot(x, A, s1, s2, B) - y_target

    sol = root_scalar(f, bracket=[x_min, x_max], method='brentq')
    return sol.root

def find_bracketsr(y_target, A, s1, s2, B, x_vals):
    f_vals = coinc_rot(x_vals, A, s1, s2, B) - y_target
    brackets = []

    for i in range(len(x_vals)-1):
        if f_vals[i] * f_vals[i+1] < 0:
            brackets.append((x_vals[i], x_vals[i+1]))

    return brackets

# %%
A_rot = 2.7050e+03 
s1_rot = 5.5130e+00 
s2_rot = 5.7952e+00 
B_rot = -7.8985e-01

# %%
x_vals = np.linspace(0, 360, 1000)
brackets = find_bracketsr(ratem5[9], A_rot, s1_rot, s2_rot, B_rot, x_vals)

print(brackets)
# Out:
# [(101.26126126126125, 101.62162162162161), (161.08108108108107, 161.44144144144144), (288.2882882882883, 288.64864864864865), (348.4684684684685, 348.8288288288288)]

# %%
print(337.5)
x = find_rot(y_target=ratem5[9], A=A_rot, s1=s1_rot, s2=s2_rot, B=B_rot, x_min=348.4684684684685, x_max=348.8288288288288)
print(x)
# Out:
# 337.5
# 348.7013882413876

# %%
x_vals = np.linspace(0, 360, 1000)
brackets = find_bracketsr(ratem5[10], A_rot, s1_rot, s2_rot, B_rot, x_vals)

print(brackets)
# Out:
# [(96.57657657657657, 96.93693693693693), (165.76576576576576, 166.1261261261261), (283.6036036036036, 283.963963963964), (353.15315315315314, 353.5135135135135)]

# %%
print(112.5)
x = find_rot(y_target=ratem5[10], A=A_rot, s1=s1_rot, s2=s2_rot, B=B_rot, x_min=96.57657657657657, x_max=96.93693693693693)
print(x)
# Out:
# 112.5
# 96.7432921441711

# %%
x_vals = np.linspace(0, 360, 1000)
brackets = find_bracketsr(ratemin10[28], A_rot, s1_rot, s2_rot, B_rot, x_vals)

print(brackets)
# Out:
# [(99.45945945945945, 99.81981981981981), (162.88288288288288, 163.24324324324323), (286.84684684684686, 287.2072072072072), (350.27027027027026, 350.6306306306306)]

# %%
print(292.5)
x = find_rot(y_target=ratemin10[28], A=A_rot, s1=s1_rot, s2=s2_rot, B=B_rot, x_min=286.84684684684686, x_max=287.2072072072072)
print(x)
# Out:
# 292.5
# 286.91814874098134

# %%
x_vals = np.linspace(0, 360, 1000)
brackets = find_bracketsr(ratemin10[24], A_rot, s1_rot, s2_rot, B_rot, x_vals)

print(brackets)
# Out:
# [(26.306306306306304, 26.666666666666664), (63.42342342342342, 63.78378378378378), (204.68468468468467, 205.04504504504504), (245.04504504504504, 245.4054054054054)]

# %%
print(22.5)
x = find_rot(y_target=ratemin10[24], A=A_rot, s1=s1_rot, s2=s2_rot, B=B_rot, x_min=26.306306306306304, x_max=26.666666666666664)
print(x)
# Out:
# 22.5
# 26.501878973592724
